# %% [markdown]
# ##Machine Learning With Python:Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if 'house_price' in file:
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/Copy of house_price_dataset.xlsx
# /content/drive/MyDrive/house_price_dataset.xlsx

# %%
import pandas as pd

train = pd.read_excel('/content/drive/MyDrive/house_price_dataset.xlsx',
                      sheet_name='Training_Data')

test = pd.read_excel('/content/drive/MyDrive/house_price_dataset.xlsx',
                     sheet_name='Testing_Data')

print(train.head())
print(test.head())
# Out:
#    Size  Price
# 0   850    120
# 1   900    128
# 2   950    135
# 3  1000    142
# 4  1050    148
#    Size  Price
# 0   980    140
# 1  1450    208
# 2  1780    255
# 3  2250    328
# 4  2675    390

# %%
# %matplotlib inline
plt.xlabel('size')
plt.ylabel('price')
plt.scatter(train.Size,train.Price,color='blue',marker='.')

# %%
train.head()
# Out:
#    Size  Price
# 0   850    120
# 1   900    128
# 2   950    135
# 3  1000    142
# 4  1050    148

# %%
train.isnull()
# Out:
#       Size  Price
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 99   False  False
# 100  False  False
# 101  False  False
# 102  False  False
# 103  False  False
#
# [104 rows x 2 columns]

# %%
train.dtypes
# Out:
# Size     int64
# Price    int64
# dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Size    104 non-null    int64
#  1   Price   104 non-null    int64
# dtypes: int64(2)
# memory usage: 1.8 KB

# %%
(train['Size'] == ' ').sum()
# Out:
# np.int64(0)

# %%
(train['Price'] == ' ').sum()
# Out:
# np.int64(0)

# %%
new_size = train.drop('Price',axis='columns')
new_size
# Out:
#      Size
# 0     850
# 1     900
# 2     950
# 3    1000
# 4    1050
# ..    ...
# 99   5800
# 100  5850
# 101  5900
# 102  5950
# 103  6000
#
# [104 rows x 1 columns]

# %%
price = train['Price']
price
# Out:
# 0      120
# 1      128
# 2      135
# 3      142
# 4      148
#       ...
# 99     860
# 100    868
# 101    875
# 102    882
# 103    890
# Name: Price, Length: 104, dtype: int64

# %%
model = linear_model.LinearRegression()
model.fit(new_size,price)
# Out:
# LinearRegression()

# %%
model.predict([[550]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72.97916889])

# %%
model.coef_
# Out:
# array([0.14987347])

# %%
model.intercept_
# Out:
# np.float64(-9.451237597354066)

# %% [markdown]
# Y = m*x b (m is coefficient and c is bias)

# %%
0.14987347*550 + -9.451237597354066
# Out:
# 72.97917090264593

# %%
test
# Out:
#    Size  Price
# 0   980    140
# 1  1450    208
# 2  1780    255
# 3  2250    328
# 4  2675    390
# 5  3120    458
# 6  3580    525
# 7  4210    622
# 8  4890    723
# 9  5750    852

# %%
new_test = test.drop(['Price'],axis='columns')
new_test
# Out:
#    Size
# 0   980
# 1  1450
# 2  1780
# 3  2250
# 4  2675
# 5  3120
# 6  3580
# 7  4210
# 8  4890
# 9  5750

# %%
new_price = test['Price']
new_price
# Out:
# 0    140
# 1    208
# 2    255
# 3    328
# 4    390
# 5    458
# 6    525
# 7    622
# 8    723
# 9    852
# Name: Price, dtype: int64

# %%
model.predict(new_test)
# Out:
# array([137.42475942, 207.86528859, 257.32353249, 327.76406167,
#        391.46028486, 458.15397738, 527.0957719 , 621.51605569,
#        723.4300128 , 852.32119385])
# array([137.42475942, 207.86528859, 257.32353249, 327.76406167,
#        391.46028486, 458.15397738, 527.0957719 , 621.51605569,
#        723.4300128 , 852.32119385])

# %%
import os

for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if 'canada' in file:
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/canada_per_capita_income.csv

# %%
df = pd.read_csv("/content/drive/MyDrive/canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
(df == ' ').sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df.year,df['per capita income (US$)'],color='blue',marker='.')

# %%
reg_model = linear_model.LinearRegression()
reg_model
# Out:
# LinearRegression()

# %%
year = df.drop(['per capita income (US$)'],axis='columns')
reg_model.fit(year,df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg_model.predict([[2020]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
