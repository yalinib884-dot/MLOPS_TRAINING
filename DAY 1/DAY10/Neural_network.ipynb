# %% [markdown]
# ## Neural Network for MNIST Dataset

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print(f"Shape of training data: {x_train.shape}")
print(f"Shape of training labels: {y_train.shape}")
print(f"Shape of test data: {x_test.shape}")
print(f"Shape of test labels: {y_test.shape}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Shape of training data: (60000, 28, 28)
# Shape of training labels: (60000,)
# Shape of test data: (10000, 28, 28)
# Shape of test labels: (10000,)

# %% [markdown]
# ### Data Preprocessing
#
# Before feeding the data into a neural network, it's essential to preprocess it. This involves:
#
# 1.  **Normalizing pixel values**: Scaling the pixel values from the range [0, 255] to [0, 1] to help the model converge faster.
# 2.  **Reshaping images**: Flattening the 28x28 images into a 784-element vector (if using a dense layer directly for the first layer, otherwise it will be done by the `Flatten` layer).
# 3.  **One-hot encoding labels**: Converting the integer labels (0-9) into a binary class matrix, which is suitable for categorical cross-entropy loss.

# %%
# Normalize the images to the range [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"Shape of training data after normalization: {x_train.shape}")
print(f"Shape of training labels after one-hot encoding: {y_train.shape}")
print(f"Shape of test data after normalization: {x_test.shape}")
print(f"Shape of test labels after one-hot encoding: {y_test.shape}")
# Out:
# Shape of training data after normalization: (60000, 28, 28)
# Shape of training labels after one-hot encoding: (60000, 10)
# Shape of test data after normalization: (10000, 28, 28)
# Shape of test labels after one-hot encoding: (10000, 10)

# %% [markdown]
# ### Building the Neural Network Model
#
# We will define a function to create a Keras Sequential model. This function will be flexible enough to allow us to specify the number of hidden layers and the number of neurons in each layer. All hidden layers will use the ReLU activation function, and the output layer will use softmax for multi-class classification.

# %%
def create_model(num_hidden_layers, neurons_per_layer):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(x_train.shape[1], x_train.shape[2])), # Flatten the 28x28 images to 784
    ])

    for _ in range(num_hidden_layers):
        model.add(keras.layers.Dense(neurons_per_layer, activation='relu'))

    model.add(keras.layers.Dense(num_classes, activation='softmax')) # Output layer with 10 classes

    return model

# Example: Create a model with 1 hidden layer and 128 neurons
sample_model = create_model(num_hidden_layers=1, neurons_per_layer=128)
sample_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# ...

# %% [markdown]
# ### Compiling, Training, and Evaluating the Sample Model
#
# Now, let's compile the `sample_model` using an appropriate optimizer, loss function, and metrics. We'll then train it on our training data and evaluate its performance on the test set.

# %%
# Compile the model
sample_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = sample_model.fit(
    x_train, y_train,
    epochs=10, # You can adjust the number of epochs
    batch_size=32,
    validation_split=0.1, # Use a portion of the training data for validation
    verbose=1
)

# Evaluate the model on the test data
loss, accuracy = sample_model.evaluate(x_test, y_test, verbose=0)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9235 - loss: 0.2684 - val_accuracy: 0.9655 - val_loss: 0.1228
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9639 - loss: 0.1204 - val_accuracy: 0.9715 - val_loss: 0.0980
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9749 - loss: 0.0826 - val_accuracy: 0.9733 - val_loss: 0.0879
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9810 - loss: 0.0621 - val_accuracy: 0.9767 - val_loss: 0.0760
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9855 - loss: 0.0468 - val_accuracy: 0.9783 - val_loss: 0.0756
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9885 - loss: 0.0374 - val_accuracy: 0.9793 - val_loss: 0.0723
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9905 - loss: 0.0310 - val_accuracy: 0.9818 - val_loss: 0.0681
# Epoch 8/10
# ...
